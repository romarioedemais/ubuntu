# %% [markdown]
# # 🐧 Ubuntu 24.04 no mybinder.org
#
# Este notebook roda em um container **Ubuntu 24.04 LTS** (Noble Numbat) [web:10].
#
# ## Como usar o terminal
#
# 1. Na página inicial do Jupyter, clique em **"New"** (canto direito)
# 2. Selecione **"Terminal"**
# 3. Você terá acesso completo ao Ubuntu!
#
# ---
#
# ## Verificando o ambiente

# %%
# Verificar versão do Ubuntu
# !cat /etc/os-release

# %%
# Verificar Python
# !python --version

# %%
# Testar pacotes
import numpy as np
import pandas as pd
print(f"numpy: {np.__version__}")
print(f"pandas: {pd.__version__}")
print("✅ Tudo funcionando!")
